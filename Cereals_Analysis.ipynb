# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Personal\\Desktop\\data sets'

# %%
os.chdir("C:/Users/Personal/Desktop/data sets")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Personal\\Desktop\\data sets'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cereals=pd.read_csv("cerealanalysis.csv")
cereals
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4              Almond_Delight   R    C       110        2    2     200    1.0
# 5     Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
# 6                 Apple_Jacks   K    C       110        2    0     125    1.0
# 7                     Basic_4   G    C       130        3    2     210    2.0
# 8                   Bran_Chex   R    C        90        2    1     200    4.0
# 9                 Bran_Flakes   P    C        90        3    0     210    5.0
# 10               Cap'n'Crunch   Q    C       120        1    2     220    0.0
# ...

# %%
cereals.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
cereals.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   74.000000  74.000000  74.000000   74.000000  74.000000  74.000000
# mean   105.540541   2.500000   0.945946  160.675676   2.090541  14.594595
# std     18.442201   1.088546   0.963610   85.188447   2.404002   4.349205
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  131.250000   0.250000  12.000000
# 50%    110.000000   2.000000   1.000000  180.000000   1.500000  14.000000
# 75%    110.000000   3.000000   1.000000  217.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  74.000000   74.000000   74.000000  74.000000  74.000000  74.000000
# mean    6.770270   92.675676   28.378378   2.175676   1.027432   0.818243
# std     4.467684   70.578065   22.787104   0.833512   0.151260   0.234914
# ...

# %%
cereals.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
cereals.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %%
cereals.hist('calories',bins=5),cereals.hist('sodium',bins=5),cereals.hist('fiber',bins=5),cereals.hist('sugars',bins=5),cereals.hist('rating',bins=5)
# Out:
# (array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D52E7D3C50>]], dtype=object),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D52E8B99B0>]], dtype=object),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D52EC2EE48>]], dtype=object),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D52EC977B8>]], dtype=object),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D52ECEABE0>]], dtype=object))

# %%
cereals.boxplot(column='calories',by='type')

# %%
cereals.boxplot(column='calories')
# Out:
# C:\Users\Personal\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
# {'boxes': [<matplotlib.lines.Line2D at 0x1d52ed674a8>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d52edc9898>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d52edcdf60>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1d52edcd278>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1d52ed672e8>,
#   <matplotlib.lines.Line2D at 0x1d52edbcf60>]}

# %%
cereals.boxplot(column='protein',by='type')

# %%
cereals.boxplot(column='calories',by='mfr')

# %%
cereals.boxplot(column='rating',by='mfr')

# %%
cereals.boxplot(column='sodium',by='mfr')

# %%
cereals.boxplot(column='sugars',by='mfr')

# %%
cereals.boxplot(column='fat',by='mfr')

# %%
cal=cereals["calories"]
rating=cereals["rating"]

# %%
plt.plot(cal,rating,'o')
plt.ylabel("Rating")
plt.xlabel("Calories")

# %%
mfr=cereals["mfr"]

# %%
plt.plot(mfr,rating,'o')
plt.ylabel("Rating")
plt.xlabel("Manufacturer").
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-3280fb4a6776> in <module>()
# ----> 1 plt.plot(mfr,rating,'o')
#       2 plt.ylabel("Rating")
#       3 plt.xlabel("Manufacturer")
#
# C:\Users\Personal\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3159         ax.hold(hold)
#    3160     try:
# -> 3161         ret = ax.plot(*args, **kwargs)
#    3162     finally:
#    3163         ax.hold(washold)
#
# C:\Users\Personal\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
#    1817                                   RuntimeWarning, stacklevel=2)
# -> 1818             return func(ax, *args, **kwargs)
#    1819         pre_doc = inner.__doc__
#    1820         if pre_doc is None:
#
# ...

# %%
cereals.cov()
# Out:
#             calories    protein       fat       sodium       fiber  \
# calories  340.114772  -1.438356  7.563865   556.479082  -15.782488
# protein    -1.438356   1.184932  0.150685    -3.698630    1.304795
# fat         7.563865   0.150685  0.928545     1.612366   -0.047094
# sodium    556.479082  -3.698630  1.612366  7257.071455  -13.788041
# fiber     -15.782488   1.304795 -0.047094   -13.788041    5.779224
# carbo      20.564606  -0.678082 -1.467419   134.387264   -3.712107
# sugars     45.125879  -1.856164  0.987412    43.650500   -1.781655
# potass   -206.945576  40.890411  8.776749  -124.572381  153.809219
# vitamins  124.861163   0.342466 -0.499815   701.453165   -1.577194
# shelf       0.520178   0.089041  0.174010    -4.229915    0.563328
# weight      2.117160   0.036781  0.032325     4.023676    0.084263
# cups        0.223565  -0.071164 -0.050781     2.616272   -0.294702
# rating   -187.529398   7.835768 -5.603623  -498.229750   20.606104
#
# ...

# %%
corr=cereals.corr()
corr
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000 -0.071648  0.425627  0.354206 -0.355982  0.256388
# protein  -0.071648  1.000000  0.143655 -0.039885  0.498610 -0.143227
# fat       0.425627  0.143655  1.000000  0.019642 -0.020329 -0.350141
# sodium    0.354206 -0.039885  0.019642  1.000000 -0.067327  0.362717
# fiber    -0.355982  0.498610 -0.020329 -0.067327  1.000000 -0.355039
# carbo     0.256388 -0.143227 -0.350141  0.362717 -0.355039  1.000000
# sugars    0.547685 -0.381669  0.229358  0.114690 -0.165885 -0.340435
# potass   -0.158991  0.532237  0.129051 -0.020719  0.906521 -0.359012
# vitamins  0.297116  0.013806 -0.022762  0.361351 -0.028791  0.259354
# shelf     0.033840  0.098137  0.216651 -0.059572  0.281135 -0.104785
# weight    0.758956  0.223383  0.221775  0.312261  0.231728  0.151341
# cups      0.051604 -0.278296 -0.224333  0.130735 -0.521842  0.357282
# rating   -0.712054  0.504070 -0.407215 -0.409548  0.600230  0.055804
#
# ...

# %%
import seaborn as sns
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
sns.distplot(cereals['rating'])

# %%
sns.distplot(cereals['protein'])

# %%
sns.distplot(cereals['calories'])

# %%
sns.distplot(cereals['fiber'])

# %%
sns.pairplot(cereals)

# %% [markdown]
# # Multiple linear regression

# %%
X=cereals[["calories","protein","fat","fiber","carbo","sugars"]]
y=cereals["rating"]

# %%
import statsmodels.api as sm
model=sm.OLS(y,X).fit()
predictions=model.predict(X)
model.summary()
# Out:
# C:\Users\Teja\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 rating   R-squared:                       0.955
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     240.4
# Date:                Fri, 21 Jun 2019   Prob (F-statistic):           9.44e-44
# Time:                        11:30:57   Log-Likelihood:                -272.24
# No. Observations:                  74   AIC:                             556.5
# Df Residuals:                      68   BIC:                             570.3
# Df Model:                           6
# ...

# %%
X=cereals.iloc[:,[3,4,5,7,8,9]].values

# %%
y=cereals.iloc[:,[15]].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=0)

# %%
X_train
# Out:
# array([[110. ,   1. ,   1. ,   0. ,  15. ,   9. ],
#        [ 50. ,   4. ,   0. ,  14. ,   8. ,   0. ],
#        [ 80. ,   2. ,   0. ,   3. ,  16. ,   0. ],
#        [120. ,   1. ,   2. ,   0. ,  12. ,  12. ],
#        [100. ,   3. ,   1. ,   3. ,  15. ,   5. ],
#        [ 90. ,   3. ,   0. ,   3. ,  20. ,   0. ],
#        [ 50. ,   2. ,   0. ,   1. ,  10. ,   0. ],
#        [110. ,   2. ,   1. ,   1. ,   9. ,  15. ],
#        [110. ,   3. ,   0. ,   3. ,  17. ,   3. ],
#        [110. ,   1. ,   1. ,   0. ,  12. ,  13. ],
#        [110. ,   2. ,   1. ,   0. ,  12. ,  12. ],
#        [110. ,   3. ,   3. ,   4. ,  10. ,   7. ],
#        [100. ,   2. ,   0. ,   0. ,  11. ,  15. ],
#        [100. ,   3. ,   1. ,   3. ,  17. ,   3. ],
#        [110. ,   3. ,   1. ,   1.5,  11.5,  10. ],
#        [110. ,   1. ,   1. ,   0. ,  12. ,  13. ],
#        [ 70. ,   4. ,   1. ,  10. ,   5. ,   6. ],
#        [100. ,   3. ,   1. ,   3. ,  17. ,   3. ],
# ...

# %%
y_train
# Out:
# array([[23.804043],
#        [93.704912],
#        [68.235885],
#        [18.042851],
#        [52.076897],
#        [72.801787],
#        [63.005645],
#        [31.230054],
#        [53.371007],
#        [22.736446],
#        [26.734515],
#        [40.448772],
#        [35.252444],
#        [49.787445],
#        [31.072217],
#        [22.396513],
#        [68.402973],
#        [51.592193],
#        [41.445019],
#        [29.509541],
#        [45.863324],
#        [64.533816],
#        [46.658844],
#        [49.120253],
#        [40.400208],
#        [31.435973],
#        [36.523683],
#        [35.782791],
#        [32.207582],
#        [40.69232 ],
#        [44.330856],
#        [39.241114],
#        [36.471512],
#        [33.983679],
#        [41.998933],
#        [19.823573],
#        [28.742414],
#        [46.895644],
#        [53.313813],
#        [27.753301],
#        [28.592785],
#        [53.131324],
#        [59.642837],
#        [40.105965]])

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
results
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions=model.predict(X_train)

# %%
accuracy=model.score(X_train,y_train)
print('Accuracy of the model: ',accuracy)
# Out:
# Accuracy of the model:  0.9377043678208358

# %%
plt.scatter(y_train,predictions)

# %%
#Evaluating the model 
from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")
# Out:
# Slope: [[-0.36262868  3.60088515 -1.39821655  1.99522231  0.72180747 -0.84204119]]
# Intercept: [64.26298529]

# %%
import numpy as np
rmse = (np.sqrt(mean_squared_error(y_train,predictions)))
r2 = r2_score(y_train,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance
# --------------------------------------
# RMSE is 3.9059435652361283
# R2 score is 0.9377043678208358
